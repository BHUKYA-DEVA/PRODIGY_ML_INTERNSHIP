# %% [markdown]
# Connected to Python 3.11.4

# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as  plt 


ds=pd.read_csv("C:/Users/bhuky/Downloads/train.csv")
ds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\bhuky\OneDrive\Desktop\C\python\MLtask1.py:2
#       1 import pandas as pd
# ----> 2 from sklearn.model_selection import train_test_split
#       3 from sklearn.linear_model import LinearRegression
#       4 from sklearn.metrics import mean_squared_error, r2_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install scikit-learn
# Out:
# ...
#
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.1/10.6 MB 1.7 MB/s eta 0:00:07
#                                               0.2/10.6 MB 2.1 MB/s eta 0:00:05
#      -                                        0.4/10.6 MB 2.9 MB/s eta 0:00:04
#      --                                       0.7/10.6 MB 3.8 MB/s eta 0:00:03
#      ----                                     1.2/10.6 MB 5.2 MB/s eta 0:00:02
#      ------                                   1.6/10.6 MB 6.0 MB/s eta 0:00:02
#      -------                                  2.1/10.6 MB 6.7 MB/s eta 0:00:02
#      ----------                               2.7/10.6 MB 7.4 MB/s eta 0:00:02
#      ------------                             3.3/10.6 MB 8.0 MB/s eta 0:00:01
#      --------------                           3.7/10.6 MB 8.2 MB/s eta 0:00:01
#      ----------------                         4.3/10.6 MB 8.6 MB/s eta 0:00:01
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as  plt 


ds=pd.read_csv("C:/Users/bhuky/Downloads/train.csv")
ds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 from sklearn.linear_model import LinearRegression
#       4 from sklearn.metrics import mean_squared_error, r2_score
# ----> 5 import matplotlib.pyplot as  plt
#       8 ds=pd.read_csv("C:/Users/bhuky/Downloads/train.csv")
#       9 ds
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.7 MB ? eta -:--:--
#                                               0.1/7.7 MB 1.1 MB/s eta 0:00:07
#      -                                        0.2/7.7 MB 2.0 MB/s eta 0:00:04
#      --                                       0.4/7.7 MB 3.1 MB/s eta 0:00:03
#      --                                       0.6/7.7 MB 3.0 MB/s eta 0:00:03
#      -----                                    1.0/7.7 MB 4.1 MB/s eta 0:00:02
#      -------                                  1.4/7.7 MB 4.9 MB/s eta 0:00:02
#      --------                                 1.7/7.7 MB 5.4 MB/s eta 0:00:02
#      -----------                              2.2/7.7 MB 6.0 MB/s eta 0:00:01
#      -------------                            2.5/7.7 MB 6.0 MB/s eta 0:00:01
#      ---------------                          2.9/7.7 MB 6.2 MB/s eta 0:00:01
#      ----------------                         3.1/7.7 MB 6.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as  plt 


ds=pd.read_csv("C:/Users/bhuky/Downloads/train.csv")
ds
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
features=["GrLivArea","BedroomAbvGr","FullBath"]

# %%
x= ds[features]

# %%
y= ds["SalePrice"]

# %%
x_train , x_test , y_train , y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)

# %%
mse=mean_squared_error(y_test, y_pred)

# %%
r2=r2_score(y_test,y_pred)

# %%
print(f'Mean Squared error: {mse}')
print(f'R-Squared: {r2}')
# Out:
# Mean Squared error: 2806426667.247853
# R-Squared: 0.6341189942328371

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual prices")
plt.ylabel("predicted prices")
plt.title("actual prices vs predicted prices")
plt.show()

# %%
new_data= pd.DataFrame({'GrLivArea':[2000], 'BedroomAbvGr':[3],'FullBath':[2]})
predicted_price= model.predict(new_data)
print(f'predicted price:{predicted_price[0]}')
# Out:
# predicted price:240377.51479736285
